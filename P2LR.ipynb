# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ewigspace1910/ReID_maket1501.git
# !cp -r /content/ReID_maket1501/P2LR-main -d /content/P2LR-main
# %cd /content/P2LR-main
# Out:
# Cloning into 'ReID_maket1501'...
# remote: Enumerating objects: 1011, done.
# remote: Counting objects: 100% (1011/1011), done.
# remote: Compressing objects: 100% (810/810), done.
# remote: Total 1011 (delta 246), reused 935 (delta 187), pack-reused 0
# Receiving objects: 100% (1011/1011), 2.89 MiB | 2.09 MiB/s, done.
# Resolving deltas: 100% (246/246), done.
# /content/P2LR-main

# %% [markdown]
# #**Training**

# %% [markdown]
# ##**Prepare data**
#
# MMT/examples/data
#
# ├── dukemtmc
#
# │   └── DukeMTMC-reID
#
# ├── market1501
#
# │   └── Market-1501-v15.09.15
#
# └── msmt17
# ....

# %%
# !mkdir datasets

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/model" "/content/models"
# %cd "/content/P2LR-main"
# Out:
# /content/P2LR-main

# %%
#market
# %cd "/content/P2LR-main/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/market.zip" -d "/content/P2LR-main/datasets/market.zip"
# !unzip "/content/P2LR-main/datasets/market.zip"  
# !rm "content/P2LR-main/datasets/market.zip"

#msmt
# %cd "/content/P2LR-main/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/MSMT17_V2.zip" -d "/content/P2LR-main/datasets/msmt.zip"
# !unzip "/content/P2LR-main/datasets/msmt.zip"
# !rm "/content/P2LR-main/datasets/msmt.zip"
# !rm -rf "/content/P2LR-main/datasets/__MACOSX"

#LPW
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/LPW.zip" -d "/content/P2LR-main/datasets/LPW.zip"
# !unzip "/content/P2LR-main/datasets/LPW.zip"
# !rm "/content/P2LR-main/datasets/LPW.zip"

#Duke
# !mkdir "/content/P2LR-main/datasets/DukeMTMC-reID"
# %cd "/content/P2LR-main/datasets/DukeMTMC-reID"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/duke.zip" -d "/content/P2LR-main/datasets/DukeMTMC-reID/DukeMTMC-reID.zip"
# !unzip "/content/P2LR-main/datasets/DukeMTMC-reID/DukeMTMC-reID.zip"

#caviar
# %cd "/content/P2LR-main/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/CAVIAR4REID.zip" -d "/content/P2LR-main/datasets/CAVIAR4REID.zip"
# !unzip "/content/P2LR-main/datasets/CAVIAR4REID.zip"
# !rm "/content/P2LR-main/datasets/CAVIAR4REID.zip"

#prai
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/PRAI-1581.zip" -d "/content/P2LR-main/datasets/3DPeS_ReId_Snap.zip"
# !unzip "/content/P2LR-main/datasets/3DPeS_ReId_Snap.zip"
# !rm "/content/P2LR-main/datasets/3DPeS_ReId_Snap.zip"
# %cd "/content/P2LR-main"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: PRAI-1581/images/00001566_0002_00000005.jpg
#   inflating: PRAI-1581/images/00001509_0002_00000015.jpg
#   inflating: PRAI-1581/images/00000246_0002_00000014.jpg
#   inflating: PRAI-1581/images/00001112_0001_00000006.jpg
#   inflating: PRAI-1581/images/00001461_0002_00000004.jpg
#   inflating: PRAI-1581/images/00001505_0001_00000008.jpg
#   inflating: PRAI-1581/images/00000191_0002_00000008.jpg
#   inflating: PRAI-1581/images/00000569_0001_00000008.jpg
#   inflating: PRAI-1581/images/00001018_0001_00000007.jpg
#   inflating: PRAI-1581/images/00001285_0001_00000001.jpg
#   inflating: PRAI-1581/images/00001089_0001_00000005.jpg
#   inflating: PRAI-1581/images/00000209_0002_00000023.jpg
#   inflating: PRAI-1581/images/00000434_0002_00000003.jpg
#   inflating: PRAI-1581/images/00001215_0001_00000008.jpg
#   inflating: PRAI-1581/images/00000989_0001_00000003.jpg
#   inflating: PRAI-1581/images/00001266_0002_00000005.jpg
# ...

# %% [markdown]
# ##pip install

# %%
# !pip3 install virtualenv
# !virtualenv theanoEnv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.8 MB 26.0 MB/s
# ...
#      |████████████████████████████████| 461 kB 61.7 MB/s
# ...
# created virtual environment CPython3.7.13.final.0-64 in 901ms
#   creator CPython3Posix(dest=/content/P2LR-main/theanoEnv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.0.4, setuptools==62.1.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/P2LR-main/theanoEnv/bin/activate; pip3 install theano
# !source /content/P2LR-main/theanoEnv/bin/activate; pip3 list
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 62.0 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 71.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 14.4 MB/s eta 0:00:00
# ...
#   Created wheel for theano: filename=Theano-1.0.5-py3-none-any.whl size=2668111 sha256=0662475f4f0996523eea5a79cc590d0657708e2e2a28d09de2bc680559e3bce1
#   Stored in directory: /root/.cache/pip/wheels/26/68/6f/745330367ce7822fe0cd863712858151f5723a0a5e322cc144
# Successfully built theano
# ...
# Package    Version
# ---------- -------
# numpy      1.21.6
# pip        22.0.4
# scipy      1.7.3
# setuptools 62.1.0
# six        1.16.0
# Theano     1.0.5
# wheel      0.37.1

# %%
# !source /content/P2LR-main/theanoEnv/bin/activate; pip install -r requirements.txt
# !source /content/P2LR-main/theanoEnv/bin/activate; pip install h5py; pip install metric-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.0/3.0 MB 14.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 776.7/776.7 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 63.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.5/26.5 MB 53.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.7/6.7 MB 55.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 26.1/26.1 MB 17.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 208.1/208.1 KB 8.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.1/10.1 MB 78.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.1/3.1 MB 47.9 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.1/4.1 MB 55.2 MB/s eta 0:00:00
# ...

# %% [markdown]
# ##**Stage 1: pretrain stage**
#
# dukemtmc -> market1501
# or
# custome -> market1501

# %%
#!sh scripts/pretrain.sh dukemtmc market1501 resnet50 1
# !source /content/P2LR-main/theanoEnv/bin/activate; python examples/source_pretrain.py \
    -ds "dukemtmc|msmt17|lpw|prai|caviara" -dt "market1501" \
    -a "resnet50"  --features 2048 --iters 10000 --print-freq 1000\
	  --num-instances 4 -b 64 -j 2 --seed 1 --margin 0.0 \
    --warmup-step 10 --lr 0.00035 --milestones 40 70  --epochs 80 --eval-step 1 \
	  --logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR/merged2market/pretrainR50s1" \
    --data-dir "/content/P2LR-main/datasets" \
    -pt "" --resume ""

# %%
#!sh scripts/pretrain.sh dukemtmc market1501 resnet50 1
# !source /content/P2LR-main/theanoEnv/bin/activate; python examples/source_pretrain.py \
    -ds "dukemtmc|msmt17|lpw|prai|caviara" -dt "market1501" \
    -a "resnet50"  --features 2048 --iters 5000 --print-freq 1000\
	  --num-instances 4 -b 64 -j 4 --seed 1 --margin 0.0 \
    --warmup-step 10 --lr 0.00035 --milestones 40 70  --epochs 80 --eval-step 5 \
	  --logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR/merged2market/pretrainR50s5000" \
    --data-dir "/content/P2LR-main/datasets" \
    -pt "" \
    --resume "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR/merged2market/pretrainR50s5000/checkpoint.pth.tar"
# Out:
# /content/P2LR-main/theanoEnv/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /content/P2LR-main/theanoEnv/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %% [markdown]
# ##**Stage 2: End to end using P2RL Framework**
#
# --num-clusters:
# > market : 500
# > duke   : 700
# > msmt   : 1000

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR" "/content/projects"

# %%
#unlabel dataset
# !mkdir '/content/datasets'
# %cd '/content/datasets'
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/UnlabelDS.zip" -d "/content/datasets/LPW.zip"
# !unzip "/content/datasets/LPW.zip"
# !rm "/content/datasets/LPW.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: UnlabelDS/bounding_box_test/006370.jpg
#   inflating: UnlabelDS/bounding_box_test/006371.jpg
#   inflating: UnlabelDS/bounding_box_test/006372.jpg
#   inflating: UnlabelDS/bounding_box_test/006373.jpg
#   inflating: UnlabelDS/bounding_box_test/006374.jpg
#   inflating: UnlabelDS/bounding_box_test/006375.jpg
#   inflating: UnlabelDS/bounding_box_test/006376.jpg
#   inflating: UnlabelDS/bounding_box_test/006377.jpg
#   inflating: UnlabelDS/bounding_box_test/006378.jpg
#   inflating: UnlabelDS/bounding_box_test/006379.jpg
#   inflating: UnlabelDS/bounding_box_test/006380.jpg
#   inflating: UnlabelDS/bounding_box_test/006381.jpg
#   inflating: UnlabelDS/bounding_box_test/006382.jpg
#   inflating: UnlabelDS/bounding_box_test/006383.jpg
#   inflating: UnlabelDS/bounding_box_test/006384.jpg
#   inflating: UnlabelDS/bounding_box_test/006385.jpg
#   inflating: UnlabelDS/bounding_box_test/006386.jpg
# ...

# %%
# %cd /content/P2LR-main
# !source /content/P2LR-main/theanoEnv/bin/activate; python examples/train_P2LR_kmeans.py \
    -dt "unlabel" -a "resnet50" -j 4  --num-clusters 1000  \
	--num-instances 4 --lr 0.00035 --iters 400 -b 64 --epochs 70 --p 0.3 \
	--soft-ce-weight 0.5 --soft-tri-weight 0.8 --dropout 0.5 --multiple_kmeans \
    --data-dir "/content/datasets" \
	--init-1 "/content/projects/merged2market/pretrainR50s1000/model_best.pth.tar" \
	--init-2 "/content/projects/merged2market/pretrainR50s1200/model_best.pth.tar" \
	--logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR/merged2market/stage2_unlabel" \
	--offline_test
# Out:
# /content/P2LR-main
# /content/P2LR-main/theanoEnv/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /content/P2LR-main/theanoEnv/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %%
#for resume
# !source /content/P2LR-main/theanoEnv/bin/activate; python examples/train_P2LR_kmeans.py \
    -dt "market1501" -a "resnet50" -j 4  --num-clusters 500  \
	--num-instances 4 --lr 0.00035 --iters 400 -b 64 --epochs 60 --p 0.3 \
	--soft-ce-weight 0.5 --soft-tri-weight 0.8 --dropout 0.5 --multiple_kmeans \
    --data-dir "/content/P2LR-main/datasets" \
	--init-1 "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR/merged2market/stage2_/model1_checkpoint.pth.tar" \
	--init-2 "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR/merged2market/stage2_/model2_checkpoint.pth.tar" \
	--logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/P2LR/merged2market/stage2_" \
	--args.offline_test
# Out:
# /content/P2LR-main/theanoEnv/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:30: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   method='lar', copy_X=True, eps=np.finfo(np.float).eps,
# /content/P2LR-main/theanoEnv/lib/python3.7/site-packages/sklearn/linear_model/least_angle.py:167: DeprecationWarning: `np.float` is a deprecated alias for the builtin `float`. To silence this warning, use `float` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.float64` here.
# ...

# %% [markdown]
# #**Testing best model**

# %%
# !sh scripts/test.sh market1501 resnet50 logs/dukemtmcTOmarket1501/resnet-P2LR-500/model_best.pth.tar
