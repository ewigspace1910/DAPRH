# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ewigspace1910/ReID_maket1501.git
# !cp -r /content/ReID_maket1501/_MixFrameworks -d /content/hahaha
# %cd /content/hahaha
# Out:
# Cloning into 'ReID_maket1501'...
# remote: Enumerating objects: 1534, done.
# remote: Counting objects: 100% (350/350), done.
# remote: Compressing objects: 100% (242/242), done.
# remote: Total 1534 (delta 165), reused 267 (delta 96), pack-reused 1184
# Receiving objects: 100% (1534/1534), 4.35 MiB | 19.63 MiB/s, done.
# Resolving deltas: 100% (565/565), done.
# /content/hahaha

# %% [markdown]
# #Data

# %% [markdown]
# ##Prepare DATA

# %%
# !mkdir datasets

# %%
# %cd '/content/hahaha/datasets'
# Out:
# /content/hahaha/datasets

# %%
#unlabel dataset with cam
# %cd '/content/hahaha/datasets'
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data/UnlabelDS.zip" -d "/content/hahaha/datasets/LPW.zip"
# !unzip "/content/hahaha/datasets/LPW.zip"
# !rm "/content/hahaha/datasets/LPW.zip"

# %%
#unlabel dataset no cam more noise
# %cd '/content/hahaha/datasets'
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data/UnlabelDS_wCamid.zip" -d "/content/hahaha/datasets/LPW.zip"
# !unzip "/content/hahaha/datasets/LPW.zip"
# !rm "/content/hahaha/datasets/LPW.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002537.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002538.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002539.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002540.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002541.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002542.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002543.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002544.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002545.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002546.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002547.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002548.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002549.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/002550.jpg
# ...

# %%
#unlabel dataset with cam ver 4 cam 80k
# %cd '/content/hahaha/datasets'
# !rm -rf "/content/hahaha/datasets/UnlabelDS_wCamid"
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data/UnlabelDS_wCamid_80k.zip" -d "/content/hahaha/datasets/LPW.zip"
# !unzip "/content/hahaha/datasets/LPW.zip"
# !rm "/content/hahaha/datasets/LPW.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016313.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016314.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016315.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016316.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016317.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016318.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016319.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016320.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016321.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016322.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016323.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016324.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016325.jpg
#   inflating: UnlabelDS_wCamid/bounding_box_test/cam_4/016326.jpg
# ...

# %% [markdown]
# #**Training**

# %% [markdown]
# ##init

# %%
# %cd /content/hahaha
# Out:
# /content/hahaha

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating Ewig_S.P_MixFramework.egg-info
# writing Ewig_S.P_MixFramework.egg-info/PKG-INFO
# writing dependency_links to Ewig_S.P_MixFramework.egg-info/dependency_links.txt
# writing requirements to Ewig_S.P_MixFramework.egg-info/requires.txt
# writing top-level names to Ewig_S.P_MixFramework.egg-info/top_level.txt
# writing manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# reading manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# writing manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build
# creating build/lib
# creating build/lib/modules
# copying modules/__init__.py -> build/lib/modules
# copying modules/dist_metric.py -> build/lib/modules
# copying modules/evaluators.py -> build/lib/modules
# copying modules/trainers.py -> build/lib/modules
# creating build/lib/modules/utils
# ...

# %% [markdown]
# ##USL

# %%
# %cd /content/hahaha
# !python examples/_finetune.py \
-dt unlabelwCam -b 64 -j 2 --num-clusters 2000 \
-a resnet50part --features 2048 \
--lr 0.00035 --alpha 0.999 --soft-ce-weight 0.5 --soft-tri-weight 0.8 \
--k 20 --beta 0.5 --aals-epoch 5 \
--epochs 50 --iters 400 --print-freq 100 \
--multiple_kmeans --fast_kmeans \
--data-dir "/content/hahaha/datasets" \
--logs-dir "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-2000wNoise" \
--init-1 "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-2500/model291_checkpoint.pth.tar" \
--init-2 "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-2500/model292_checkpoint.pth.tar" \
--offline_test
# Out:
# /content/hahaha
# ...
# Args:Namespace(aals_epoch=5, alpha=0.999, arch='resnet50part', batch_size=64, beta=0.5, data_dir='/content/hahaha/datasets', dataset_target='unlabelwCam', dropout=0, epochs=50, eval_step=1, fast_kmeans=True, features=2048, height=256, init_1='/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-2500/model291_checkpoint.pth.tar', init_2='/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-2500/model292_checkpoint.pth.tar', iters=400, k=20, logs_dir='/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-2000wNoise', lr=0.00035, momentum=0.9, moving_avg_momentum=0, multiple_kmeans=True, num_clusters=2000, num_instances=4, offline_test=True, p=0.2, part=3, print_freq=100, seed=1, soft_ce_weight=0.5, soft_tri_weight=0.8, weight_decay=0.0005, width=128, workers=2)
# ...
# => Unlabel with CamID DataSet loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
# ...

# %%
# %cd /content/hahaha
# !python examples/_finetune.py \
-dt unlabelwCam -b 64 -j 2 --num-clusters 3000 \
-a resnet50part --features 2048 \
--lr 0.00035 --alpha 0.999 --soft-ce-weight 0.5 --soft-tri-weight 0.8 \
--k 20 --beta 0.5 --aals-epoch 5 \
--epochs 40 --iters 200 --print-freq 50 \
--multiple_kmeans --fast_kmeans \
--data-dir "/content/hahaha/datasets" \
--logs-dir "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-3000w80k40up" \
--init-1 "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-3000w80k40up/model51_checkpoint.pth.tar" \
--init-2 "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-3000w80k40up/model52_checkpoint.pth.tar" \
--offline_test
# Out:
# /content/hahaha
# ...
# Args:Namespace(aals_epoch=5, alpha=0.999, arch='resnet50part', batch_size=64, beta=0.5, data_dir='/content/hahaha/datasets', dataset_target='unlabelwCam', dropout=0, epochs=40, eval_step=1, fast_kmeans=True, features=2048, height=256, init_1='/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-3000w80k40up/model51_checkpoint.pth.tar', init_2='/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-3000w80k40up/model52_checkpoint.pth.tar', iters=200, k=20, logs_dir='/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/phase2-3000w80k40up', lr=0.00035, momentum=0.9, moving_avg_momentum=0, multiple_kmeans=True, num_clusters=3000, num_instances=4, offline_test=True, p=0.2, part=3, print_freq=50, seed=1, soft_ce_weight=0.5, soft_tri_weight=0.8, weight_decay=0.0005, width=128, workers=2)
# ...
# => Unlabel with CamID DataSet loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
# ...

# %% [markdown]
# #TEST
