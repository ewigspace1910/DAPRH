# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/hoahoa1808/distance-evaluate
# Out:
# Cloning into 'distance-evaluate'...
# remote: Enumerating objects: 52, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (33/33), done.
# remote: Total 52 (delta 17), reused 52 (delta 17), pack-reused 0
# Unpacking objects: 100% (52/52), done.

# %%
# !mkdir "/content/distance-evaluate/data_dir"

# %%
# !cp /content/drive/MyDrive/ducanh/Nautilus/data/Test_SCID.zip "/content/distance-evaluate/data_dir/sicd.zip"
# !cp "/content/drive/MyDrive/ducanh/Nautilus/data/Test_Canifa.zip" "/content/distance-evaluate/data_dir/sicd.zip"

# %%
# %cd "/content/distance-evaluate/data_dir"
# Out:
# /content/distance-evaluate/data_dir

# %%
# !unzip /content/distance-evaluate/data_dir/sicd.zip
# Out:
# Archive:  /content/distance-evaluate/data_dir/sicd.zip
#    creating: Test_Canifa/1/
#   inflating: Test_Canifa/1/cam_3_006113.jpg
#   inflating: Test_Canifa/1/cam_3_006125.jpg
#   inflating: Test_Canifa/1/cam_3_006129.jpg
#   inflating: Test_Canifa/1/cam_3_006134.jpg
#   inflating: Test_Canifa/1/cam_3_006374.jpg
#   inflating: Test_Canifa/1/cam_3_006381.jpg
#    creating: Test_Canifa/102/
#   inflating: Test_Canifa/102/cam_2_008200.jpg
#   inflating: Test_Canifa/102/cam_2_008212.jpg
#   inflating: Test_Canifa/102/cam_2_008214.jpg
#   inflating: Test_Canifa/102/cam_2_008222.jpg
#   inflating: Test_Canifa/102/cam_2_008230.jpg
#   inflating: Test_Canifa/102/cam_2_008239.jpg
#   inflating: Test_Canifa/102/cam_2_008243.jpg
#    creating: Test_Canifa/105/
#   inflating: Test_Canifa/105/cam_2_008259.jpg
#   inflating: Test_Canifa/105/cam_2_008520.jpg
#   inflating: Test_Canifa/105/cam_2_008581.jpg
#   inflating: Test_Canifa/105/cam_2_008600.jpg
#    creating: Test_Canifa/107/
# ...

# %%
# %cd /content
# Out:
# /content

# %%
# !rm -rf /content/distance-evaluate/pretrained
# !cp -r /content/drive/MyDrive/ducanh/Nautilus/projects/Mix/f2048/onnx /content/distance-evaluate/pretrained

# %% [markdown]
# #test case

# %%
# %cd /content/distance-evaluate
# Out:
# /content/distance-evaluate

# %%
# !pip install onnxruntime
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 4.9 MB 12.5 MB/s
# ...
#      |████████████████████████████████| 46 kB 3.3 MB/s
# ...
#      |████████████████████████████████| 86 kB 5.0 MB/s
# ...

# %%
# !python /content/distance-evaluate/tools/reformat.py -c "/content/distance-evaluate/config.yml"

# %%
# !python /content/distance-evaluate/run.py -c "/content/distance-evaluate/config.yml"

# %%
# !python /content/distance-evaluate/run.py -c "/content/distance-evaluate/config.yml"
# Out:
# ╒═════════════════╤═══════════════════════════════════════════════════════════════════════╕
# │ keys            │ values                                                                │
# ╞═════════════════╪═══════════════════════════════════════════════════════════════════════╡
# │ data_name       │ 'scid1'                                                               │
# ├─────────────────┼───────────────────────────────────────────────────────────────────────┤
# │ cache_dir       │ PosixPath('/content/datasets/eval_cache/data/scid1')                  │
# ├─────────────────┼───────────────────────────────────────────────────────────────────────┤
# │ cache_path      │ PosixPath('/content/datasets/eval_cache/data/scid1/scid1_data.cache') │
# ├─────────────────┼───────────────────────────────────────────────────────────────────────┤
# │ data_dir        │ PosixPath('/content/distance-evaluate/data_dir/Test_Canifa')          │
# ...
