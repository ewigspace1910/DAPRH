# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ewigspace1910/ReID_maket1501.git
# !cp -r /content/ReID_maket1501/LF2-main LF2
# !rm -rf /content/ReID_maket1501
# %cd /content/LF2
# Out:
# Cloning into 'ReID_maket1501'...
# remote: Enumerating objects: 1017, done.
# remote: Counting objects: 100% (1017/1017), done.
# remote: Compressing objects: 100% (816/816), done.
# remote: Total 1017 (delta 248), reused 939 (delta 187), pack-reused 0
# Receiving objects: 100% (1017/1017), 3.08 MiB | 13.83 MiB/s, done.
# Resolving deltas: 100% (248/248), done.
# /content/LF2

# %% [markdown]
# #**Prepare dataset**
#
# LF2/dataset
#
# ├── dukemtmc
#
# │ └── DukeMTMC-reID
#
# ├── market1501
#
# │ └── Market-1501-v15.09.15
#
# └── msmt17 ....
#
# │ └── ....
#
# └── unlabelds ....

# %%
#market
# %cd "/content/LF2/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/market.zip" -d "/content/LF2/datasets/market.zip"
# !unzip "/content/LF2/datasets/market.zip"  
# !rm "content/LF2/datasets/market.zip"

# %%
#msmt
# %cd "/content/LF2/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/MSMT17_V2.zip" -d "/content/LF2/datasets/msmt.zip"
# !unzip "/content/LF2/datasets/msmt.zip"
# !rm "/content/LF2/datasets/msmt.zip"
# !rm -rf "/content/LF2/datasets/__MACOSX"

#LPW
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/LPW.zip" -d "/content/LF2/datasets/LPW.zip"
# !unzip "/content/LF2/datasets/LPW.zip"
# !rm "/content/LF2/datasets/LPW.zip"

#Duke
# !mkdir "/content/LF2/datasets/DukeMTMC-reID"
# %cd "/content/LF2/datasets/DukeMTMC-reID"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/duke.zip" -d "/content/LF2/datasets/DukeMTMC-reID/DukeMTMC-reID.zip"
# !unzip "/content/LF2/datasets/DukeMTMC-reID/DukeMTMC-reID.zip"

# %%
#unlabel dataset
# %cd "/content/LF2/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/UnlabelDS.zip" -d "/content/LF2/datasets/LPW.zip"
# !unzip "/content/LF2/datasets/LPW.zip"
# !rm "/content/LF2/datasets/LPW.zip"

# %%
# %cd /content/LF2
# Out:
# /content/LF2

# %% [markdown]
# #**Training**

# %% [markdown]
# ##pip install

# %%
# !pip3 install virtualenv
# !virtualenv theanoEnv

# %%
# !source /content/LF2/theanoEnv/bin/activate; pip3 install theano
# !source /content/LF2/theanoEnv/bin/activate; pip3 list

# %%
# !source /content/LF2/theanoEnv/bin/activate; pip install -r requirements.txt
# !source /content/LF2/theanoEnv/bin/activate; pip install h5py; pip install metric-learn

# %%
# %cd /content/LF2

# %% [markdown]
# ##phase 1: pretrain

# %%
# for example, duke-to-market
# !python source_pretrain.py -ds duke -dt market \
    --data-dir "/content/LF2/datasets" \
    --logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1" \
    --b 64 -j 4 --num-instances 4 \
    -a resnet50_source \
    --iters 250 --print-freq 50 \
    --features 0 \
    --resume "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1/checkpoint.pth.tar"
# Out:
# ...
# Args:Namespace(arch='resnet50_source', batch_size=64, data_dir='/content/LF2/datasets', dataset_source='duke', dataset_target='market', dropout=0, epochs=80, eval_step=5, evaluate=False, features=0, height=256, iters=250, logs_dir='/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1', lr=0.00035, margin=0.0, milestones=[40, 70], momentum=0.9, num_instances=4, print_freq=50, rerank=False, resume='/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1/checkpoint.pth.tar', seed=1, warmup_step=10, weight_decay=0.0005, width=128, workers=4)
# ...
# => DukeMTMC-reID loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
#   train    |   702 |    16522 |         8
#   query    |   702 |     2228 |         8
#   gallery  |  1110 |    17661 |         8
#   ----------------------------------------
# => Market1501 loaded
# Dataset statistics:
# ...

# %%
# for example, duke-to-market
# !python source_pretrain.py -ds duke -dt market \
    --data-dir "/content/LF2/datasets" \
    --logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1000" \
    --b 64 -j 4 --num-instances 4 \
    -a resnet50_source \
    --iters 1000 --print-freq 250 \
    --features 0 \
    --resume "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1000/checkpoint.pth.tar"
# Out:
# ...
# Args:Namespace(arch='resnet50_source', batch_size=64, data_dir='/content/LF2/datasets', dataset_source='duke', dataset_target='market', dropout=0, epochs=80, eval_step=5, evaluate=False, features=0, height=256, iters=1000, logs_dir='/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1000', lr=0.00035, margin=0.0, milestones=[40, 70], momentum=0.9, num_instances=4, print_freq=250, rerank=False, resume='', seed=1, warmup_step=10, weight_decay=0.0005, width=128, workers=4)
# ...
# => DukeMTMC-reID loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
#   train    |   702 |    16522 |         8
#   query    |   702 |     2228 |         8
#   gallery  |  1110 |    17661 |         8
#   ----------------------------------------
# => Market1501 loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
# ...

# %%
# for example, merge-to-market
# !python source_pretrain.py -ds custome -dt market \
    --data-dir "/content/LF2/datasets" \
    --logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1" \
    --b 64 -j 4 --num-instances 4 \
    -a resnet50_source \
    --iters 250 --print-freq 50 \
    --features 0 \
    --resume "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1/checkpoint.pth.tar"

# %% [markdown]
# ##phase 2: Finetune training

# %%
# %cd /content/LF2
# Out:
# /content/LF2

# %%
# for example, duke-to-market
# !python target_train.py -dt unlabel \
    --data-dir "/content/LF2/datasets" \
    --logs-dir "/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1" \
    --print-freq 100 \
    -b 64 -j 4 --num-clusters 700 \
    # --resume ""
# Out:
# ...
# Args:Namespace(alpha=0.999, arch='resnet50', batch_size=64, data_dir='/content/LF2/datasets', dataset_target='unlabel', dropout=0, epochs=80, eval_step=1, features=0, height=256, initial_weights='logs_duke_pretrained_multi_gpu', iters=400, logs_dir='/content/drive/MyDrive/Colab Notebooks/Nautilus/projects/FL2/d2m/pretrain1', lr=0.00035, momentum=0.9, num_clusters=700, num_instances=4, print_freq=100, resume='', seed=1, split_parts=2, weight_decay=0.0005, width=128, workers=4)
# ...
# => UnlabelDS loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
#   train    |     1 |    11262 |         1
#   query    |     1 |      107 |         1
#   gallery  |     1 |    11262 |         1
#   ----------------------------------------
# ==>not using cut at pooling!
# 	 num_features : 0
# 	 num_classes
# ==> create 3 linear layer
# Traceback (most recent call last):
# ...

# %% [markdown]
# #**Evaluate**

# %%
# for example, duke-to-market
# !python model_test.py -dt market --data-dir PATH/TO/DATA --resume PATH/TO/CHECKPOINTS
