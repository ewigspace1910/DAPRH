# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ewigspace1910/ReID_maket1501.git
# !cp -r /content/ReID_maket1501/LF2-main LF2
# !rm -rf /content/ReID_maket1501
# %cd /content/LF2
# Out:
# Cloning into 'ReID_maket1501'...
# remote: Enumerating objects: 1350, done.
# remote: Counting objects: 100% (166/166), done.
# remote: Compressing objects: 100% (117/117), done.
# remote: Total 1350 (delta 88), reused 116 (delta 45), pack-reused 1184
# Receiving objects: 100% (1350/1350), 3.88 MiB | 11.70 MiB/s, done.
# Resolving deltas: 100% (488/488), done.
# /content/LF2

# %% [markdown]
# #**Prepare dataset**
#
# LF2/dataset
#
# ├── dukemtmc
#
# │ └── DukeMTMC-reID
#
# ├── market1501
#
# │ └── Market-1501-v15.09.15
#
# └── msmt17 ....
#
# │ └── ....
#
# └──NoisyShoppingMall
#
# └── unlabelds ....

# %%
#NoisyShoppingMall
# %cd "/content/LF2/datasets"
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data/psuedo.zip" -d "/content/LF2/datasets/3DPeS_ReId_Snap.zip"
# !unzip "/content/LF2/datasets/3DPeS_ReId_Snap.zip"
# !rm "/content/LF2/datasets/3DPeS_ReId_Snap.zip"
# %cd "/content/LF2"
# Out:
# Streaming output truncated to the last 5000 lines.
#    creating: content/psuedo_label_1/1146/
#   inflating: content/psuedo_label_1/1146/000838.jpg
#   inflating: content/psuedo_label_1/1146/008663.jpg
#   inflating: content/psuedo_label_1/1146/000831.jpg
#   inflating: content/psuedo_label_1/1146/000847.jpg
#   inflating: content/psuedo_label_1/1146/008678.jpg
#   inflating: content/psuedo_label_1/1146/008672.jpg
#    creating: content/psuedo_label_1/5/
#   inflating: content/psuedo_label_1/5/004876.jpg
#   inflating: content/psuedo_label_1/5/003823.jpg
#   inflating: content/psuedo_label_1/5/006663.jpg
#    creating: content/psuedo_label_1/325/
#   inflating: content/psuedo_label_1/325/009952.jpg
#   inflating: content/psuedo_label_1/325/006135.jpg
#   inflating: content/psuedo_label_1/325/002114.jpg
#   inflating: content/psuedo_label_1/325/000866.jpg
#   inflating: content/psuedo_label_1/325/000872.jpg
#    creating: content/psuedo_label_1/971/
# ...

# %%
#market
# %cd "/content/LF2/datasets"
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data/market.zip" -d "/content/LF2/datasets/market.zip"
# !unzip "/content/LF2/datasets/market.zip"  
# !rm "content/LF2/datasets/market.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Market-1501-v15.09.15/gt_query/1180_c2s2_164677_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c3s3_006062_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c3s3_006062_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c4s5_038360_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c4s5_038360_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c5s3_006593_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c5s3_006593_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c6s3_029892_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c6s3_029892_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1181_c1s5_041166_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1181_c1s5_041166_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1181_c2s3_000162_00_good.mat
# ...

# %%
#msmt
# %cd "/content/LF2/datasets"
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data/MSMT17_V2.zip" -d "/content/LF2/datasets/msmt.zip"
# !unzip "/content/LF2/datasets/msmt.zip"
# !rm "/content/LF2/datasets/msmt.zip"
# !rm -rf "/content/LF2/datasets/__MACOSX"

#LPW
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data

# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 10.1 MB 6.7 MB/s
# ...
#      |████████████████████████████████| 461 kB 51.0 MB/s
# ...
# created virtual environment CPython3.7.13.final.0-64 in 1416ms
#   creator CPython3Posix(dest=/content/LF2/theanoEnv, clear=False, no_vcs_ignore=False, global=False)
#   seeder FromAppData(download=False, pip=bundle, setuptools=bundle, wheel=bundle, via=copy, app_data_dir=/root/.local/share/virtualenv)
#     added seed packages: pip==22.1.2, setuptools==62.6.0, wheel==0.37.1
#   activators BashActivator,CShellActivator,FishActivator,NushellActivator,PowerShellActivator,PythonActivator

# %%
# !source /content/LF2/theanoEnv/bin/activate; pip3 install theano
# !source /content/LF2/theanoEnv/bin/activate; pip3 list
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.8/2.8 MB 33.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 15.7/15.7 MB 58.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 38.1/38.1 MB 11.9 MB/s eta 0:00:00
# ...
#   Created wheel for theano: filename=Theano-1.0.5-py3-none-any.whl size=2668109 sha256=de092504640f598d2469f67d704ae96e2a49816634726a5a568b0410881b8a03
#   Stored in directory: /root/.cache/pip/wheels/26/68/6f/745330367ce7822fe0cd863712858151f5723a0a5e322cc144
# Successfully built theano
# ...
# Package    Version
# ---------- -------
# numpy      1.21.6
# pip        22.1.2
# scipy      1.7.3
# setuptools 62.6.0
# six        1.16.0
# Theano     1.0.5
# wheel      0.37.1

# %%
# !source /content/LF2/theanoEnv/bin/activate; pip install -r requirements.txt
# !source /content/LF2/theanoEnv/bin/activate; pip install h5py; pip install metric-learn
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 38.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.5/14.5 MB 61.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.3/4.3 MB 67.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.8/24.8 MB 14.2 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 804.1/804.1 MB 2.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.4/17.4 MB 50.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 307.0/307.0 kB 6.1 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.21.6
#     Uninstalling numpy-1.21.6:
#       Successfully uninstalled numpy-1.21.6
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# %cd /content/LF2
# Out:
# /content/LF2

# %% [markdown]
# ##phase 1: pretrain

# %%
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/projects/FL2" "/content/projects"

# %%
# for example, duke-to-market
# !python source_pretrain.py -ds custome -dt market \
#     --data-dir "/content/LF2/datasets" \
#     --logs-dir "/content/drive/MyDrive/ducanh/Nautilus/projects/FL2/phase1_1000" \
#     --b 64 -j 2 --num-instances 2 \
#     -a resnet50_source \
#     --iters 1000 --print-freq 200 \
#     --features 0 \
#     --resume "/content/drive/MyDrive/ducanh/Nautilus/projects/FL2/phase1_1000/checkpoint.pth.tar"

# %%
#@title allds2market1501 resnet50 1
# !python source_pretrain.py -ds custome -dt market \
    --data-dir "/content/LF2/datasets" \
    --logs-dir "/content/drive/MyDrive/ducanh/Nautilus/projects/FL2/phase1_1250wNoisy" \
    --b 64 -j 2 --num-instances 4 \
    -a resnet50_source \
    --iters 1200 --print-freq 100 \
    # --resume "/content/projects/phase1_1200wNoisy/checkpoint.pth.tar"
        # --features 2048 \
# Out:
# ...
# Args:Namespace(arch='resnet50_source', batch_size=64, data_dir='/content/LF2/datasets', dataset_source='custome', dataset_target='market', dropout=0, epochs=80, eval_step=5, evaluate=False, features=0, height=256, iters=1200, logs_dir='/content/drive/MyDrive/ducanh/Nautilus/projects/FL2/phase1_1250wNoisy', lr=0.00035, margin=0.0, milestones=[40, 70], momentum=0.9, num_instances=4, print_freq=100, rerank=False, resume='', seed=1, warmup_step=10, weight_decay=0.0005, width=128, workers=2)
# ...
# => DukeMTMC-reID loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
#   train    |   702 |    16522 |         8
#   query    |   702 |     2228 |         8
#   gallery  |  1110 |    17661 |         8
#   ----------------------------------------
# => MSMT loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
# ...
