# %%
# !git clone https://github.com/ewigspace1910/ReID_maket1501.git
# !cp -r /content/ReID_maket1501/_MixFrameworks /content/hahaha
# Out:
# Cloning into 'ReID_maket1501'...
# remote: Enumerating objects: 2006, done.
# remote: Counting objects: 100% (295/295), done.
# remote: Compressing objects: 100% (226/226), done.
# remote: Total 2006 (delta 121), reused 236 (delta 69), pack-reused 1711
# Receiving objects: 100% (2006/2006), 4.72 MiB | 14.33 MiB/s, done.
# Resolving deltas: 100% (868/868), done.

# %%
# !python /content/ReID_maket1501/_MixFrameworks/setup.py install
# !python /content/ReID_maket1501/_MixFrameworks/deepstream/cpp/setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating Ewig_S.P_MixFramework.egg-info
# writing Ewig_S.P_MixFramework.egg-info/PKG-INFO
# writing dependency_links to Ewig_S.P_MixFramework.egg-info/dependency_links.txt
# writing requirements to Ewig_S.P_MixFramework.egg-info/requires.txt
# writing top-level names to Ewig_S.P_MixFramework.egg-info/top_level.txt
# writing manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# reading manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# writing manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# ...
#
# creating build
# creating build/bdist.linux-x86_64
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/EGG-INFO
# copying Ewig_S.P_MixFramework.egg-info/PKG-INFO -> build/bdist.linux-x86_64/egg/EGG-INFO
# copying Ewig_S.P_MixFramework.egg-info/SOURCES.txt -> build/bdist.linux-x86_64/egg/EGG-INFO
# ...

# %%
# !cp -r /content/drive/MyDrive/ducanh/Nautilus/projects/Mix/f2048/canifa/600 /content/models

# %% [markdown]
# #COVERT

# %%
# %cd /content/hahaha/deepstream/scripts
# Out:
# /content/hahaha/deepstream/scripts

# %%
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/model201_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/model241_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/model281_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/model321_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/model361_checkpoint.pth.tar
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# ...

# %%
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/40up/model121_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/40up/model161_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/40up/model201_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/40up/model241_checkpoint.pth.tar
# !python export_onnx.py -a resnet50 --feature 2048 --resume /content/models/40up/model81_checkpoint.pth.tar
# Out:
# The Zen of Python, by Tim Peters
#
# Beautiful is better than ugly.
# Explicit is better than implicit.
# Simple is better than complex.
# Complex is better than complicated.
# Flat is better than nested.
# Sparse is better than dense.
# Readability counts.
# Special cases aren't special enough to break the rules.
# Although practicality beats purity.
# Errors should never pass silently.
# Unless explicitly silenced.
# In the face of ambiguity, refuse the temptation to guess.
# There should be one-- and preferably only one --obvious way to do it.
# Although that way may not be obvious at first unless you're Dutch.
# Now is better than never.
# Although never is often better than *right* now.
# If the implementation is hard to explain, it's a bad idea.
# If the implementation is easy to explain, it may be a good idea.
# Namespaces are one honking great idea -- let's do more of those!
# ...

# %%
fs = ["/content/models/model251_checkpoint.onnx",
      "/content/models/model301_checkpoint.onnx",
      "/content/models/model351_checkpoint.onnx",
      "/content/models/model352_checkpoint.onnx"]

# %%
# !rm -rf "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/f2048/onnx"
# !mkdir "/content/drive/MyDrive/ducanh/ReID_model/Feature-768/P2LR-R50-40k"

# %%
import subprocess

for path in fs:
    newname = path.split("/")[-1]
    bashCommand = "cp {} /content/drive/MyDrive/ducanh/ReID_model/Feature-768/P2LR-R50-40k/{}".format(path, newname)
    process = subprocess.Popen(bashCommand.split(), stdout=subprocess.PIPE)
    output, error = process.communicate()
    print(output, error)
