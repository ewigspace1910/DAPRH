# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !rm -rf "/content/sample_data"

# %%
# !git clone "https://github.com/ewigspace1910/ReID_maket1501.git"
# !cp -rf "/content/ReID_maket1501" -d "/content/sskd-master"
# Out:
# Cloning into 'ReID_maket1501'...
# remote: Enumerating objects: 741, done.
# remote: Counting objects: 100% (741/741), done.
# remote: Compressing objects: 100% (608/608), done.
# remote: Total 741 (delta 142), reused 721 (delta 126), pack-reused 0
# Receiving objects: 100% (741/741), 2.77 MiB | 12.85 MiB/s, done.
# Resolving deltas: 100% (142/142), done.

# %% [markdown]
# #DATASET

# %%
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/model" "/content/models"
# %cd "/content/sskd-master"
# Out:
# /content/sskd-master

# %%
#Duke
# !mkdir "/content/sskd-master/datasets/DukeMTMC-reID"
# %cd "/content/sskd-master/datasets/DukeMTMC-reID"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/duke.zip" -d "/content/sskd-master/datasets/DukeMTMC-reID/DukeMTMC-reID.zip"
# !unzip "/content/sskd-master/datasets/DukeMTMC-reID/DukeMTMC-reID.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: bounding_box_train/4215_c8_f0042228.jpg
#   inflating: bounding_box_train/4215_c8_f0042348.jpg
#   inflating: bounding_box_train/4215_c8_f0042468.jpg
#   inflating: bounding_box_train/4215_c8_f0042588.jpg
#   inflating: bounding_box_train/4215_c8_f0042708.jpg
#   inflating: bounding_box_train/4216_c6_f0063434.jpg
#   inflating: bounding_box_train/4216_c6_f0063554.jpg
#   inflating: bounding_box_train/4216_c6_f0063674.jpg
#   inflating: bounding_box_train/4216_c6_f0063794.jpg
#   inflating: bounding_box_train/4216_c6_f0063914.jpg
#   inflating: bounding_box_train/4216_c6_f0064034.jpg
#   inflating: bounding_box_train/4216_c6_f0064154.jpg
#   inflating: bounding_box_train/4216_c7_f0068113.jpg
#   inflating: bounding_box_train/4216_c7_f0068233.jpg
#   inflating: bounding_box_train/4216_c7_f0068353.jpg
#   inflating: bounding_box_train/4216_c7_f0068473.jpg
#   inflating: bounding_box_train/4216_c7_f0068593.jpg
# ...

# %%
#market
# %cd "/content/sskd-master/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/market.zip" -d "/content/sskd-master/datasets/market.zip"
# !unzip "/content/sskd-master/datasets/market.zip"  
# !rm "content/sskd-master/datasets/market.zip"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: Market-1501-v15.09.15/gt_query/1180_c2s2_164677_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c3s3_006062_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c3s3_006062_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c4s5_038360_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c4s5_038360_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c5s3_006593_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c5s3_006593_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c6s3_029892_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1180_c6s3_029892_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1181_c1s5_041166_00_good.mat
#   inflating: Market-1501-v15.09.15/gt_query/1181_c1s5_041166_00_junk.mat
#   inflating: Market-1501-v15.09.15/gt_query/1181_c2s3_000162_00_good.mat
# ...

# %%
#msmt
# %cd "/content/sskd-master/datasets"
# !cp -r "/content/drive/MyDrive/Colab Notebooks/Nautilus/data/MSMT17_V2.zip" -d "/content/sskd-master/datasets/msmt.zip"
# !unzip "/content/sskd-master/datasets/msmt.zip"
# !rm "/content/sskd-master/datasets/msmt.zip"
# !rm -rf "/content/sskd-master/datasets/__MACOSX"
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_033_15_0114noon_1545_1_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_034_15_0114noon_1546_0.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_035_15_0114noon_1546_0_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_036_15_0114noon_1548_1.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_037_15_0114noon_1548_1_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_038_15_0114noon_1549_0.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_039_15_0114noon_1549_0_ex.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909_040_15_0114noon_1550_1.jpg
#   inflating: MSMT17_V2/mask_train_v2/0909/0909
#   inflating: PRAI-1581/images/00001018_0001_00000007.jpg
#   inflating: PRAI-1581/images/00001285_0001_00000001.jpg
#   inflating: PRAI-1581/images/00001089_0001_00000005.jpg
#   inflating: PRAI-1581/images/00000209_0002_00000023.jpg
#   inflating: PRAI-1581/images/00000434_0002_00000003.jpg
#   inflating: PRAI-1581/images/00001215_0001_00000008.jpg
#   inflating: PRAI-1581/images/00000989_0001_00000003.jpg
# ...

# %% [markdown]
# #**TRAINING**

# %% [markdown]
# ##install requirements by PIP

# %%
# !pip install yacs
# !pip install pillow
# !pip install termcolor
# !pip install tabulate
# !pip install tensorboard
# !pip install faiss-cpu
# !pip install torch==1.9.1+cu111 torchvision==0.10.1+cu111 torchaudio==0.9.1 -f https://download.pytorch.org/whl/torch_stable.html

# !git clone https://github.com/NVIDIA/apex
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      |████████████████████████████████| 8.6 MB 4.0 MB/s
# ...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# ...

# %%
# %cd apex
# !pip install -v --disable-pip-version-check --no-cache-dir --global-option="--cpp_ext" --global-option="--cuda_ext" ./
# Out:
# /content/sskd-master/datasets/apex
# /usr/local/lib/python3.7/dist-packages/pip/_internal/commands/install.py:232: UserWarning: Disabling all use of wheels due to the use of --build-option / --global-option / --install-option.
#   cmdoptions.check_install_build_global(options)
# Using pip 21.1.3 from /usr/local/lib/python3.7/dist-packages/pip (python 3.7)
# Value for scheme.platlib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.purelib does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/lib/python3.7/dist-packages
# sysconfig: /usr/lib/python3.7/site-packages
# Value for scheme.headers does not match. Please report this to <https://github.com/pypa/pip/issues/9617>
# distutils: /usr/local/include/python3.7/UNKNOWN
# sysconfig: /usr/include/python3.7m/UNKNOWN
# ...

# %% [markdown]
# ##stage 1
#
# Train a student model (r50-ibn) and a teacher model (r101_ibn), you can run:

# %%
# %cd /content/sskd-master
# !python projects/Basic_Project/train_net.py --config-file "/content/sskd-master/projects/Basic_Project/configs/r50-ibn.yml"
#!python projects/Basic_Project/train_net.py --config-file "/content/sskd-master/projects/Basic_Project/configs/r50-ibn.yml" --resume
# Out:
# /content/sskd-master
# ./fastreid/evaluation/rank.py:15: UserWarning: Cython rank evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython rank evaluation (very fast so highly recommended) is '
# ./fastreid/evaluation/roc.py:19: UserWarning: Cython roc evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython roc evaluation (very fast so highly recommended) is '
# Command Line Args: Namespace(config_file='/content/sskd-master/projects/Basic_Project/configs/r50-ibn.yml', dist_url='tcp://127.0.0.1:49153', eval_only=False, machine_rank=0, num_gpus=1, num_machines=1, opts=[], resume=False)
# [06/14 02:32:38 fastreid]: Rank of current process: 0. World size: 1
# [06/14 02:32:39 fastreid]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.7.13 (default, Apr 24 2022, 01:04:09) [GCC 7.5.0]
# ...

# %%
# %cd /content/sskd-master
# !python projects/Basic_Project/train_net.py --config-file "/content/sskd-master/projects/Basic_Project/configs/r101-ibn.yml"
# Out:
# /content/sskd-master
# ./fastreid/evaluation/rank.py:15: UserWarning: Cython rank evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython rank evaluation (very fast so highly recommended) is '
# ./fastreid/evaluation/roc.py:19: UserWarning: Cython roc evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython roc evaluation (very fast so highly recommended) is '
# Command Line Args: Namespace(config_file='/content/sskd-master/projects/Basic_Project/configs/r101-ibn.yml', dist_url='tcp://127.0.0.1:49153', eval_only=False, machine_rank=0, num_gpus=1, num_machines=1, opts=[], resume=True)
# [06/10 05:41:53 fastreid]: Rank of current process: 0. World size: 1
# [06/10 05:41:54 fastreid]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.7.13 (default, Apr 24 2022, 01:04:09) [GCC 7.5.0]
# ...

# %% [markdown]
# ##stage 2
#
#
# Train the student model based unlabeled dataset and sskd, you can run:

# %%
# %cd /content/sskd-master
# Out:
# /content/sskd-master

# %%
# !python projects/SSKD/train_net.py --config-file projects/SSKD/configs/sskd.yml --num-gpu 1
# Out:
# ./fastreid/evaluation/rank.py:15: UserWarning: Cython rank evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython rank evaluation (very fast so highly recommended) is '
# ./fastreid/evaluation/roc.py:19: UserWarning: Cython roc evaluation (very fast so highly recommended) is unavailable, now use python evaluation.
#   'Cython roc evaluation (very fast so highly recommended) is '
# Command Line Args: Namespace(config_file='projects/SSKD/configs/sskd.yml', dist_url='tcp://127.0.0.1:49153', eval_only=False, machine_rank=0, num_gpus=1, num_machines=1, opts=[], resume=False)
# [06/14 01:49:35 fastreid]: Rank of current process: 0. World size: 1
# [06/14 01:49:36 fastreid]: Environment info:
# ----------------------  ----------------------------------------------------------------
# sys.platform            linux
# Python                  3.7.13 (default, Apr 24 2022, 01:04:09) [GCC 7.5.0]
# numpy                   1.21.6
# ...

# %% [markdown]
# #**TMP**
