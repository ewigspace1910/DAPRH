# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !git clone https://github.com/ewigspace1910/ReID_maket1501.git
# !cp -r /content/ReID_maket1501/_MixFrameworks -d /content/hahaha
# %cd /content/hahaha

# %% [markdown]
# # **Data**

# %% [markdown]
# ##Prepare DATA

# %%
# %cd "/content/hahaha/"
# !mkdir datasets
# %cd '/content/hahaha/datasets'
# Out:
# /content/hahaha
# /content/hahaha/datasets

# %%
#unlabel dataset with cam ver 4 cam 20k
# %cd '/content/hahaha/datasets'
# !rm -rf "/content/hahaha/datasets/UnlabelDS_canifa"
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/data/UnlabelDS_canifa.zip" -d "/content/hahaha/datasets/LPW.zip"
# !unzip "/content/hahaha/datasets/LPW.zip"
# !rm "/content/hahaha/datasets/LPW.zip"

# %% [markdown]
# #**Training**

# %% [markdown]
# ##init

# %%
# %cd /content/hahaha
# !rm -rf "/content/hahaha/Ewig_S.P_MixFramework.egg-info"
# Out:
# /content/hahaha

# %%
# !python setup.py install
# Out:
# running install
# running bdist_egg
# running egg_info
# creating Ewig_S.P_MixFramework.egg-info
# writing Ewig_S.P_MixFramework.egg-info/PKG-INFO
# writing dependency_links to Ewig_S.P_MixFramework.egg-info/dependency_links.txt
# writing requirements to Ewig_S.P_MixFramework.egg-info/requires.txt
# writing top-level names to Ewig_S.P_MixFramework.egg-info/top_level.txt
# writing manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# reading manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# writing manifest file 'Ewig_S.P_MixFramework.egg-info/SOURCES.txt'
# installing library code to build/bdist.linux-x86_64/egg
# running install_lib
# running build_py
# creating build/bdist.linux-x86_64/egg
# creating build/bdist.linux-x86_64/egg/modules
# creating build/bdist.linux-x86_64/egg/modules/utils
# copying build/lib/modules/utils/rerank.py -> build/bdist.linux-x86_64/egg/modules/utils
# ...

# %% [markdown]
# ##PHASE 2

# %% [markdown]
# ### UC + Cross agreement

# %%
# !rm -rf "content/projects"
# !cp -r "/content/drive/MyDrive/ducanh/Nautilus/projects/_phase1" "/content/projects"

# %%
# %cd /content/hahaha
# !python examples/_finetune.py -dt canifa -b 64 -j 2 --num-clusters 880 \
-a resnet50part --features 768 \
--lr 0.00035 --alpha 0.999 --soft-ce-weight 0.5 --soft-tri-weight 0.8 \
--epochs 80 --iters 250 --print-freq 50 --eval-step 5 \
--data-dir "/content/hahaha/datasets" \
--logs-dir "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/f768/canifa/r50-880" \
--init-1 "/content/projects/r50c/model_best.pth.tar" \
--init-2 "/content/projects/r50a/model_best.pth.tar" \
--offline_test \
--flag-ca --k 20 --beta 0.25 --aals-epoch 5 --part 2 --fast_kmeans --extra-bottleneck

# %% [markdown]
# ### DBSCAN

# %%
# %cd /content/hahaha
# !python examples/_finetune.py -dt canifa -b 16 -j 2 --num-clusters 900 \
-a resnet50 --features 768 \
--lr 0.00035 --alpha 0.999 --soft-ce-weight 0.5 --soft-tri-weight 0.8 \
--epochs 80 --iters 400 --print-freq 50 --eval-step 5 \
--data-dir "/content/hahaha/datasets" \
--logs-dir "/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/f768/canifa/dbscan" \
--init-1 "/content/projects/r50c/model_best.pth.tar" \
--init-2 "/content/projects/r50f/model_best.pth.tar" \
--offline_test \
--dbscan --dbscan-k1 25
# Out:
# /content/hahaha
# ...
# Args:Namespace(aals_epoch=5, alpha=0.999, arch='resnet50', batch_size=16, beta=0.5, data_dir='/content/hahaha/datasets', dataset_target='canifa', dbscan=True, dbscan_k1=25, dbscan_k2=6, dropout=0, epochs=80, eps=0.5, eval_step=5, extra_bottleneck=False, fast_kmeans=False, features=768, flag_ca=False, height=256, init_1='/content/projects/r50c/model_best.pth.tar', init_2='/content/projects/r50f/model_best.pth.tar', iters=400, k=20, logs_dir='/content/drive/MyDrive/ducanh/Nautilus/projects/Mix/f768/canifa/dbscan', lr=0.00035, momentum=0.9, moving_avg_momentum=0, num_clusters=900, num_instances=4, offline_test=True, p=0.2, part=3, print_freq=50, seed=1, soft_ce_weight=0.5, soft_tri_weight=0.8, weight_decay=0.0005, width=128, workers=2)
# ...
# => Unlabel with CamID DataSet loaded
# Dataset statistics:
#   ----------------------------------------
#   subset   | # ids | # images | # cameras
#   ----------------------------------------
# ...

# %% [markdown]
# #TEST
